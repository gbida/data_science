# %% [markdown]
# # 서울지하철데이터 pandas로 분석하기
#
# - Tmoney 대중교통 통계자료 > 2022년 6월 교통카드 데이터 > 지하철 유무임별 이용현황
# - 승차비율 50% 이하인 지하철역

# %%
import pandas as pd

subway = pd.read_csv('./data/seoul_subway.csv', encoding='utf-8')
subway.head()
# Out:
#        사용월  호선명  역ID  지하철역     유임승차     유임하차    무임승차    무임하차
# 0  2022-06  1호선  150   서울역  1150754  1123193  194717  187155
# 1  2022-06  1호선  151    시청   537067   543569   80671   78279
# 2  2022-06  1호선  152    종각   834173   815704  131987  121717
# 3  2022-06  1호선  153  종로3가   450317   404106  299617  278151
# 4  2022-06  1호선  154  종로5가   394420   404105  254236  244555

# %%
# 빈 값이 있는지 확인
subway.isnull().sum()
# Out:
# 사용월     0
# 호선명     0
# 역ID     0
# 지하철역    0
# 유임승차    0
# 유임하차    0
# 무임승차    0
# 무임하차    0
# dtype: int64

# %%
# 데이터 수정 위해서 subway2 생성
subway2 = subway.copy()

# %%
# 전체탑승객, 유임승차비율, 무임승차비율 데이터 추가
subway2['전체탑승객'] = subway['유임승차'] + subway['무임승차']
subway2['유임승차비율'] = round((subway2['유임승차']  / subway2['전체탑승객']) * 100, 1)
subway2['무임승차비율'] = round((subway2['무임승차']  / subway2['전체탑승객']) * 100, 1)
subway2.head()
# Out:
#        사용월  호선명  역ID  지하철역     유임승차     유임하차    무임승차    무임하차    전체탑승객  유임승차비율  \
# 0  2022-06  1호선  150   서울역  1150754  1123193  194717  187155  1345471    85.5
# 1  2022-06  1호선  151    시청   537067   543569   80671   78279   617738    86.9
# 2  2022-06  1호선  152    종각   834173   815704  131987  121717   966160    86.3
# 3  2022-06  1호선  153  종로3가   450317   404106  299617  278151   749934    60.0
# 4  2022-06  1호선  154  종로5가   394420   404105  254236  244555   648656    60.8
#
#    무임승차비율
# 0    14.5
# 1    13.1
# 2    13.7
# 3    40.0
# 4    39.2

# %%
# 승차비율 50% 이하인 지하철역

# %% [markdown]
# ---
# ## 출퇴근 시간대별 이용현황

# %%
import pandas as pd


pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 50)

# %pip install xlrd
subwayDF = pd.read_excel('subway.xls',\
	sheet_name='지하철 시간대별 이용현황',\
	header=[0, 1], thousands=',')
subwayDF.head(3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\lh\공공데이터분석\subway_pandas.ipynb 셀 8 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/Users/lh/%EA%B3%B5%EA%B3%B5%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D/subway_pandas.ipynb#ch0000006?line=4'>5</a> pd.set_option('display.max_rows', 50)
#       <a href='vscode-notebook-cell:/c%3A/Users/lh/%EA%B3%B5%EA%B3%B5%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D/subway_pandas.ipynb#ch0000006?line=6'>7</a> # %pip install xlrd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lh/%EA%B3%B5%EA%B3%B5%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D/subway_pandas.ipynb#ch0000006?line=7'>8</a> subwayDF = pd.read_excel('subway.xls',\
#       <a href='vscode-notebook-cell:/c%3A/Users/lh/%EA%B3%B5%EA%B3%B5%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D/subway_pandas.ipynb#ch0000006?line=8'>9</a> 	sheet_name='지하철 시간대별 이용현황',\
#      <a href='vscode-notebook-cell:/c%3A/Users/lh/%EA%B3%B5%EA%B3%B5%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D/subway_pandas.ipynb#ch0000006?line=9'>10</a> 	header=[0, 1], thousands=',')
#      <a href='vscode-notebook-cell:/c%3A/Users/lh/%EA%B3%B5%EA%B3%B5%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D/subway_pandas.ipynb#ch0000006?line=10'>11</a> subwayDF.head(3)
#
# File c:\Users\lh\Programs\Python3.9.13\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\lh\Programs\Python3.9.13\lib\site-packages\pandas\io\excel\_base.py:457, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455 if not isinstance(io, ExcelFile):
#     456     should_close = True
# --> 457     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     458 elif engine and engine != io.engine:
#     459     raise ValueError(
#     460         "Engine should not be specified when passing "
#     461         "an ExcelFile - ExcelFile already has the engine set"
#     462     )
#
# File c:\Users\lh\Programs\Python3.9.13\lib\site-packages\pandas\io\excel\_base.py:1376, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1374     ext = "xls"
#    1375 else:
# -> 1376     ext = inspect_excel_format(
#    1377         content_or_path=path_or_buffer, storage_options=storage_options
#    1378     )
#    1379     if ext is None:
#    1380         raise ValueError(
#    1381             "Excel file format cannot be determined, you must specify "
#    1382             "an engine manually."
#    1383         )
#
# File c:\Users\lh\Programs\Python3.9.13\lib\site-packages\pandas\io\excel\_base.py:1250, in inspect_excel_format(content_or_path, storage_options)
#    1247 if isinstance(content_or_path, bytes):
#    1248     content_or_path = BytesIO(content_or_path)
# -> 1250 with get_handle(
#    1251     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1252 ) as handle:
#    1253     stream = handle.handle
#    1254     stream.seek(0)
#
# File c:\Users\lh\Programs\Python3.9.13\lib\site-packages\pandas\io\common.py:795, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#    (...)
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
# --> 795         handle = open(handle, ioargs.mode)
#     796     handles.append(handle)
#     798 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'subway.xls'

# %%
commuteDF = subwayDF.iloc[:, [1, 3, 10, 12, 14]]
commuteDF.head(3)
# Out:
#                  호선명               지하철역 07:00:00~07:59:59 08:00:00~08:59:59  \
#   Unnamed: 1_level_1 Unnamed: 3_level_1                승차                승차
# 0                1호선                서울역             39233             65106
# 1                1호선                 시청              6647              8294
# 2                1호선                 종각              5814              9612
#
#   09:00:00~09:59:59
#                  승차
# 0             54833
# 1              9211
# 2             11847

# %%
commuteDF.dtypes
# Out:
# 호선명                Unnamed: 1_level_1    object
# 지하철역               Unnamed: 3_level_1    object
# 07:00:00~07:59:59  승차                    object
# 08:00:00~08:59:59  승차                    object
# 09:00:00~09:59:59  승차                    object
# dtype: object

# %%
# instead thousands parameter
# for column in commuteDF.iloc[:, 2:]:
	# column.apply(lambda x: x.replace(',', ''))

# %%
# 7~9시까지의 승차 데이터 타입 object -> int64로 변경
commuteDF.iloc[:, 2:].astype('int64')
commuteDF.iloc[:, 2:].dtypes
# Out:
# 07:00:00~07:59:59  승차    int64
# 08:00:00~08:59:59  승차    int64
# 09:00:00~09:59:59  승차    int64
# dtype: object

# %%
commuteDF.iloc[:, :].head(3)
# Out:
#                  호선명               지하철역 07:00:00~07:59:59 08:00:00~08:59:59  \
#   Unnamed: 1_level_1 Unnamed: 3_level_1                승차                승차
# 0                1호선                서울역             39233             65106
# 1                1호선                 시청              6647              8294
# 2                1호선                 종각              5814              9612
#
#   09:00:00~09:59:59
#                  승차
# 0             54833
# 1              9211
# 2             11847

# %%
# 7~9시까지의 승차인원 데이터 추가
total = commuteDF.sum(axis=1, numeric_only=True)
commuteDF.insert(len(commuteDF.columns), '7~9시까지 승차인원', total)
commuteDF
# Out:
#                    호선명               지하철역 07:00:00~07:59:59 08:00:00~08:59:59  \
#     Unnamed: 1_level_1 Unnamed: 3_level_1                승차                승차
# 0                  1호선                서울역             39233             65106
# 1                  1호선                 시청              6647              8294
# 2                  1호선                 종각              5814              9612
# 3                  1호선               종로3가              4746              8589
# 4                  1호선               종로5가              5020              8550
# ..                 ...                ...               ...               ...
# 610                신림선                 당곡              7708             11603
# 611                신림선                 신림              3099              5402
# 612                신림선                 서원              8427             12646
# 613                신림선            서울대벤처타운             16194             22232
# 614                신림선           관악산(서울대)              4086              4382
#
#     09:00:00~09:59:59 7~9시까지 승차인원
#                    승차
# 0               54833      159172
# 1                9211       24152
# 2               11847       27273
# 3               13179       26514
# 4               11925       25495
# ..                ...         ...
# 610              6862       26173
# 611              2941       11442
# 612              7590       28663
# 613             13280       51706
# 614              3446       11914
#
# [615 rows x 6 columns]
